# %% [markdown]
# ## Python Assignment 2: Data Structures - List, Dictionary, Set & Conditional Statements

# %% [markdown]
# ### List (Creation, Modification and Access):

# %% [markdown]
# #### 1. List Creation:

# %% [markdown]
# ##### a. Create a list named age_list with five integer elements. For eg., [24, 25, 26, 27, 28]

# %%
Age_List=[24,25,26,27,28]
print(Age_List)
# Out:
# [24, 25, 26, 27, 28]

# %%
type(Age_List)
# Out:
# list

# %% [markdown]
# ##### b. Create a list named name_list with five string elements.

# %%
name_list=["Sai","Aarudh","Amar","Anbu","Ahalya"]
print(name_list)
# Out:
# ['Sai', 'Aarudh', 'Amar', 'Anbu', 'Ahalya']

# %% [markdown]
# #### 2. List Operations / Modifications:

# %% [markdown]
# ##### a. Append the string "Yazhini" to name_list.

# %%
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Sai', 'Aarudh', 'Amar', 'Anbu', 'Ahalya', 'Yazhini']

# %% [markdown]
# ##### b. Insert the element 30 at index 2 in age_list.

# %%
Age_List.insert(2,30)
print(Age_List)
# Out:
# [24, 25, 30, 26, 27, 28]

# %% [markdown]
# ##### c. Remove the string "Yazhini" from name_list.

# %%
name_list.remove("Yazhini")
print(name_list)
# Out:
# ['Sai', 'Aarudh', 'Amar', 'Anbu', 'Ahalya']

# %% [markdown]
# ##### d. Pop the last element from age_list.

# %%
Age_List.pop()
print(Age_List)
# Out:
# [24, 25, 30, 26, 27]

# %% [markdown]
# ##### e. Extend the age_list with additional ages [29, 30, 26].

# %%
Age_List.extend([29,30,26])
print(Age_List)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %% [markdown]
# ##### f. Sort age_list in descending order.

# %%
Age_List.sort(reverse=True)
print(Age_List)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %% [markdown]
# ##### g. Find Max age, Min age and sum of all ages from age_list.

# %%
Max_Age=max(Age_List)
Min_Age=min(Age_List)
Sum_Age=sum(Age_List)
print(f"Max Age:{Max_Age}\nMin Age:{Min_Age}\nSum of Age_List:{Sum_Age}\n")
# Out:
# Max Age:30
# Min Age:24
# Sum of Age_List:217

# %% [markdown]
# #### 3. Accessing List Elements:

# %% [markdown]
# ##### a. Print the first element of name_list.

# %%
print(name_list[0])
# Out:
# Sai

# %% [markdown]
# ##### b. Print the last element of name_list.

# %%
print(name_list[-1])
# Out:
# Ahalya

# %% [markdown]
# ##### c. Print the elements from index 2 to index 4 in name_list.

# %%
print(name_list[2:5])
# Out:
# ['Amar', 'Anbu', 'Ahalya']

# %% [markdown]
# ##### d. Print the elements of name_list in reverse order.

# %%
print(name_list[::-1])
# Out:
# ['Ahalya', 'Anbu', 'Amar', 'Aarudh', 'Sai']

# %% [markdown]
# ### Dictionary (Creation, Modification and Access):

# %% [markdown]
# #### a. Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100).

# %%
student_marks={"Ram":96,"Seetha":100,"Lakshmana":85,"Hanuman":88,"Kowsalya":90}
print(student_marks)
# Out:
# {'Ram': 96, 'Seetha': 100, 'Lakshmana': 85, 'Hanuman': 88, 'Kowsalya': 90}

# %%
type(student_marks)
# Out:
# dict

# %% [markdown]
# #### b. Access and print the mark of a specific student, of your choice.

# %%
print(student_marks["Ram"])
# Out:
# 96

# %%
name = input("Enter student name: ")
print("Mark:", student_marks[name])
# Out:
# Enter student name:  Hanuman
# Mark: 88

# %%
name = input("Enter student name: ")
print("Mark:", student_marks[name])
# Out:
# Enter student name:  Seetha
# Mark: 100

# %% [markdown]
# #### c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.

# %%
student_marks.update({"Janani":80})
print("Added new Student-",student_marks)
# Out:
# Added new Student- {'Ram': 96, 'Seetha': 100, 'Lakshmana': 85, 'Hanuman': 88, 'Kowsalya': 90, 'Janani': 80}

# %% [markdown]
# #### d. Update the mark of any one older student to 82.

# %%
student_marks.update({"Seetha":82})
print(student_marks)
# Out:
# {'Ram': 96, 'Seetha': 82, 'Lakshmana': 85, 'Hanuman': 88, 'Kowsalya': 90, 'Janani': 80}

# %% [markdown]
# #### e. Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary.

# %%
s1=student_marks.keys()
s2=student_marks.values()
s3=student_marks.items()
print(f"--------------Keys,Values & Key-Value Pairs------------:\n{s1}\n{s2}\n{s3}")
# Out:
# --------------Keys,Values & Key-Value Pairs------------:
# dict_keys(['Ram', 'Seetha', 'Lakshmana', 'Hanuman', 'Kowsalya', 'Janani'])
# dict_values([96, 82, 85, 88, 90, 80])
# dict_items([('Ram', 96), ('Seetha', 82), ('Lakshmana', 85), ('Hanuman', 88), ('Kowsalya', 90), ('Janani', 80)])

# %% [markdown]
# ### Sets (Operations):

# %% [markdown]
# #### a. Create a set called my_set with following values:['a','e','i','o','u','a','a','i']-Analyse the output and provide explanation for the same.

# %%
my_set={'a','e','i','o','u','a','a','i'}
print(f"{my_set} is a set\nSet is an unordered collection of unique elements,it doesnt allow duplicates\nSo a,a,i in my_set didnt appear")
# Out:
# {'e', 'o', 'a', 'u', 'i'} is a set
# Set is an unordered collection of unique elements,it doesnt allow duplicates
# So a,a,i in my_set didnt appear

# %% [markdown]
# #### b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.

# %%
my_set[4]='s'
my_set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 my_set[4]='s'
#       2 my_set
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# ###### Shows TypeError:'set' object does not support item assignment
# ###### Sets are unordered and do not support indexing.so this code throws error

# %% [markdown]
# #### c. Create two sets:
#
# ##### set1 with values: {1, 3, 5, 7, 9}
# ##### set2 with values: {2, 3, 5, 8, 10}

# %%
set1={1,3,5,7,9}
set2={2,3,5,8,10}
print("Set1:",set1,"\nSet2:",set2)
# Out:
# Set1: {1, 3, 5, 7, 9}
# Set2: {2, 3, 5, 8, 10}

# %%
type(set1)
# Out:
# set

# %%
type(set2)
# Out:
# set

# %% [markdown]
# #### d. Compute and print the union and intersection of set1 and set2.

# %%
print(set1.union(set2))
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
print(set1.intersection(set2))
# Out:
# {3, 5}

# %%
Union=set1 | set2
Intersection=set1 & set2
print(f"Union:{Union}\nIntersection:{Intersection}")
# Out:
# Union:{1, 2, 3, 5, 7, 8, 9, 10}
# Intersection:{3, 5}

# %% [markdown]
# ### Operators & Conditional Statements :(IF, ELIF, ELSE)

# %% [markdown]
# #### Performance Category Program:

# %% [markdown]
# ##### 1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
# ##### 2. Find the performance category based on the input score using following criteria:
# ###### a. Above Average: Score greater than 7
# ###### b. Average: Score between 4 and 7(both inclusive)
# ###### c. Below Average: Score lesser than 4
# ##### 3. Output: Print the Performance category
# ##### 4. Additional Step: You can give a prompt of your choice to each category.
# ###### For eg: If score below average “Need to Improve your performance, consistent practice will lead to better results”.

# %%
Score=int(input("Enter the Score(0-10):"))
if Score>7:
    print("Above Average:Excellent Performance! Keep it up.")
elif Score>=4 and Score<=7 :
    print("Average:Good work!Keep Practicing.")
else:
    print("Below Average:Needs Improvement")
# Out:
# Enter the Score(0-10): 10
# Above Average:Excellent Performance! Keep it up.
